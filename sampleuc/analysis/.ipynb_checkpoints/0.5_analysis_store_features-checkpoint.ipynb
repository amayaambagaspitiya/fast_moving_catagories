# %%
# %run "C:\Users\amayaa\OneDrive - John Keells Holdings PLC\Desktop\sampleuc\src\common\utils\runscipt.ipynb"

# %%
# %run "C:\Users\amayaa\OneDrive - John Keells Holdings PLC\Desktop\sampleuc\src\model\run_scripts.ipynb"

# %%
# %run "C:\Users\amayaa\OneDrive - John Keells Holdings PLC\Desktop\sampleuc\pipelines\0.1_create_mastertable.ipynb"

# %%
# Aggregate sales data by outlet and number of competitors
agg_df = (store_features_with_primarykey.groupBy("stg_outlet_cd", "stg_no_of_compet_supermarket_val").agg(
    f.count("stg_outlet_cd").alias("number_of_sales")
).orderBy("stg_outlet_cd", "stg_no_of_compet_supermarket_val"))
agg_df.show()
# Out:
# +-------------+--------------------------------+---------------+
# |stg_outlet_cd|stg_no_of_compet_supermarket_val|number_of_sales|
# +-------------+--------------------------------+---------------+
# |            A|                               2|            585|
# |            B|                               2|            585|
# |            C|                               0|            585|
# +-------------+--------------------------------+---------------+

# %%
master_table_pandas = master_table.toPandas()
plt.bar(master_table_pandas['stg_outlet_cluster_cat'],master_table_pandas['next_week_qty'])
plt.title('Outlet cluster vs Next Week\'s Sales')
plt.xlabel('Outlet cluster')
plt.ylabel('Next Week\'s Sales')
plt.show()

# %%
master_table_pandas = master_table.toPandas()
plt.bar(master_table_pandas['stg_no_of_compet_supermarket_val'],master_table_pandas['next_week_qty'])
plt.title('number of competetors in area vs Next Week\'s Sales')
plt.xlabel('number of competetors in area')
plt.ylabel('Next Week\'s Sales')
plt.show()
# Out:
# 2024-07-03 14:01:29,316 - matplotlib.category - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-07-03 14:01:29,316 - matplotlib.category - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.

# %%
# Convert Spark DataFrame to Pandas DataFrame for visualization
master_table_pandas = master_table.toPandas()
plt.bar(master_table_pandas['stg_outlet_profile_cat'],master_table_pandas['next_week_qty'])
plt.title('Outlet profile category  vs Next Week\'s Sales')
plt.xlabel('Outlet profile category')
plt.ylabel('Next Week\'s Sales')
plt.show()
